# %%
import numpy as np
import contextily as cx
import osmnx
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
cities = gpd.read_file("sp_blg_adbscan_city_boundaries_v1.gpkg")

# %%
cities.shape
# Out:
# (717, 3)

# %%
streets = gpd.read_file("final_tile.geojson.geojson")

# %%
pois = osmnx.geometries_from_place("Madrid, Spain", tags={"amenity": "bar"})
# Out:
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\osmnx\geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))

# %%
cities.head()
# Out:
#   city_id  n_buildings                                           geometry
# 0   ci000         2348  POLYGON ((385390.071 4202949.446, 384488.697 4...
# 1   ci001         2741  POLYGON ((214893.033 4579137.558, 215258.185 4...
# 2   ci002         5472  POLYGON ((690674.281 4182188.538, 691047.526 4...
# 3   ci003        14608  POLYGON ((513378.282 4072327.639, 513408.853 4...
# 4   ci004         2324  POLYGON ((206989.081 4129478.031, 207275.702 4...

# %%
cities.plot();
# Out:
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\geopandas\plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\setuptools\_distutils\version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
cities.loc[4,'geometry']

# %%
streets.plot()
# Out:
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\geopandas\plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\setuptools\_distutils\version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\geopandas\plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\setuptools\_distutils\version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# <AxesSubplot:>

# %%
streets.loc[0, 'geometry']

# %%
pois.plot(alpha=0.4)
# Out:
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\geopandas\plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\setuptools\_distutils\version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\geopandas\plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\setuptools\_distutils\version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# <AxesSubplot:>

# %%
f, ax = plt.subplots(1)
cities.plot(ax=ax)
ax.set_title("Cities")
ax.set_axis_off();
# Out:
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\geopandas\plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# C:\Users\USER\miniconda3\envs\geodata\lib\site-packages\setuptools\_distutils\version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
