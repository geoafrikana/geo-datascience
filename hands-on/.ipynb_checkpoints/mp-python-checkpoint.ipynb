# %%
import numpy as np
import contextily as cx
import osmnx
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
cities = gpd.read_file("sp_blg_adbscan_city_boundaries_v1.gpkg")

# %%
cities.shape
# Out:
# (717, 3)

# %%
streets = gpd.read_file("final_tile.geojson.geojson")

# %%
streets
# Out:
#                                       name         id  \
# 0               Plaza Virgen de la Capilla  123483746
# 1           Plaza Nuestra Señora del Prado  123483930
# 2        Avenida del Cardenal Herrera Oria    4272448
# 3      Glorieta de Mariano Salvador Maella    4292687
# 4                      Calle de Pedro Rico    4292689
# ...                                    ...        ...
# 10375            Avenida del General Perón  801691271
# 10376               Calle de Matilde Landa  801923267
# 10377               Calle de Matilde Landa  801923268
# 10378               Calle de Matilde Landa  801923274
# 10379               Calle de Matilde Landa  801923275
#
#                                     wikipedia_link  gender scale category  \
# 0                                                   Female              -
# 1                                                   Female              -
# 2                                                     Male           None
# ...
